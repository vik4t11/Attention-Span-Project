# %% [markdown]
# # Project Reference Notes

# %% [markdown]
# ### Introduction

# %% [markdown]
# In this Jupyter Notebook I am immersing myself in the content from the Code Institute LMS to brace myself for the FIRST summative exam. I will include notes I can reference when processing the dataset provided by my tutor Emma. Intialising my workspace in a virtual environment is important because I need to isolate myself from the global terminal to avoid error codes in this notebook when I install my dependencies including Numpy and Pandas.

# %%
pip install numpy
# Out:
# ...
#   Using cached numpy-2.5.2-cp312-cp312-macosx_10_13_x86_64.whl.metadata (6.6 kB)
# Using cached numpy-2.5.2-cp312-cp312-macosx_10_13_x86_64.whl (16.9 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %% [markdown]
# I have successfully installed Numpy overcoming a 'Module Not Found Error' which led me to deleting the entire project several times. In this notebook I have learned I can install the dependency directly in the kernal before importing it as np. I have been fixated on getting it installed in the terminal instead. I have included a print screen of the solution suggested by copilot in VS Code.

# %% [markdown]
# ! (![Module-Error-Screenshot-2026-08-14 .png](<attachment:Module-Error-Screenshot-2026-08-14 .png>))

# %% [markdown]
# TUTOR QUESTION: How do I hide the markdown coding for an image !()

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-3.0.5-cp312-cp312-macosx_10_13_x86_64.whl.metadata (79 kB)
# ...
# Using cached pandas-3.0.5-cp312-cp312-macosx_10_13_x86_64.whl (10.4 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# So far I have setup my virtual environment, intialised the GitHub repositry to commit changes throughout my project and installed the dependencies I will be using to analyse the dataset from Kaggle.
